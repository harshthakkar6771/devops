# %%
import pandas as pd
import numpy as np
import os
import datetime
import cv2
import face_recognition

path='F:\\images'                          #path in which images are stored 
images=[]                                  #list which contains images
personname=[]
mylist=os.listdir(path)                   #list of the images which is stored in folder
encodelist=[]

for i in mylist:                          
    image=cv2.imread(f'{path}/{i}')
    images.append(image)
    personname.append(os.path.splitext(i)[0])
    print(personname)
def faceencodings(images):
    encodelist=[]
    for img in images:
        img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        encode=face_recognition.face_encodings(img)[0]
        encodelist.append(encode)
    return encodelist

encodelist=faceencodings(images)
print(encodelist)
print("all encodings complete")

cap=cv2.VideoCapture(1)

while True:
    ret, frame=cap.read()
    faces=cv2.resize(frame, (0,0), None, 0.25, 0.25)
    faces=cv2.cvtColor(faces, cv2.COLOR_BGR2RGB)
    
    facescurrentframe=face_recognition.face_locations(faces)
    encodecurrentframe=face_recognition.face_encodings(faces, facescurrentframe)
    
    for encodeface, faceloc in zip(encodecurrentframe, facescurrentframe):
        matches=face_recognition.compare_faces(encodelist, encodeface)
        facedis=face_recognition.face_distance(encodelist, encodeface)
        matchindex=np.argmin(facedis)
        
        if matches[matchindex]:
            name=personname[matchindex].upper()
            y1,x2,y2,x1=faceloc
            y1,x2,y2,x1=y1*4,x2*4,y2*4,x1*4
            cv2.rectangle(frame, (x1,y2),(x2,y1),(255,0,0),2)
            cv2.rectangle(frame, (x1,y2-35),(x2,y2),(255,0,0),cv2.FILLED)
            cv2.putText(frame, name, (x1+6,y2+6),cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,230), 2)
            
    cv2.imshow("camera",frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ['nana']
# ['nana', 'sonu']
# ['nana', 'sonu', 'papa']
# [array([-0.11741429,  0.03023843,  0.01471921,  0.02094129,  0.02119763,
#        -0.16850202, -0.00848997, -0.15036322,  0.19036405, -0.0733137 ,
#         0.20641932, -0.02857614, -0.16998088, -0.16846994,  0.10583422,
#         0.10858998, -0.14092903, -0.12589805, -0.1209487 , -0.11900086,
#         0.06873703, -0.04503986,  0.12485416,  0.07363988, -0.15100972,
#        -0.33565825, -0.04547969, -0.15182868,  0.02097092, -0.06602503,
#         0.03626379,  0.08895612, -0.20917076, -0.10520924, -0.00059768,
#         0.08944498, -0.02153747,  0.02525855,  0.27774134, -0.03010475,
#        -0.23110931, -0.00269618, -0.02968237,  0.23365666,  0.27299917,
#        -0.00254851, -0.00454115, -0.02881166,  0.11786747, -0.277318  ,
#         0.04881166,  0.16810271,  0.04559106,  0.03873814,  0.12715369,
#        -0.09138366, -0.01017194,  0.05928189, -0.19233327,  0.05550978,
# ...

# %%
import pandas as pd
import numpy as np
import os
import datetime
import cv2
import face_recognition

path='F:\\images'                          #path in which images are stored 
images=[]                                  #list which contains images
personname=[]
mylist=os.listdir(path)                   #list of the images which is stored in folder


for i in mylist:                          
    image=cv2.imread(f'{path}/{i}')
    img=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    encode=face_recognition.face_encodings(img)[0]

cap=cv2.VideoCapture(0)
   q
while True:
    
    ret, frame = cap.read()
    face=face_recognition.face_locations(image)
    y1,x2,y2,x1=face[0]
    encode=face_recognition.face_encodings(img,face)
    image = cv2.rectangle(frame, (x1,y2),(x2,y1),(255,0,0), 2) 
    cv2.imshow("camera", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [2], in <cell line: 21>()
#      23 ret, frame = cap.read()
#      24 face=face_recognition.face_locations(image)
# ---> 25 y1,x2,y2,x1=face[0]
#      26 encode=face_recognition.face_encodings(img,face)
#      27 image = cv2.rectangle(frame, (x1,y2),(x2,y1),(255,0,0), 2)
#
# IndexError: list index out of range
